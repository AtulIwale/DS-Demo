# %%
print('Hello World')
# Out:
# Hello World

# %%
A = 1
print(A)
# Out:
# 1

# %%
True+False
# Out:
# 1

# %%
True-True
# Out:
# 0

# %%
True+True+True-False
# Out:
# 3

# %%
True&True
# Out:
# True

# %%
True&False
# Out:
# False

# %%
False&False
# Out:
# False

# %%
1+3
# Out:
# 4

# %%
6-3
# Out:
# 3

# %%
33-22
# Out:
# 11

# %%
x=10
y='Hello'
print(y+str(x))
# Out:
# Hello10
